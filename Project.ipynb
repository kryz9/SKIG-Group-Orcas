# %%
# !pip install pyngrok==4.1.1
# !pip install flask-ngrok
# !ngrok authtoken '2XYKAH6vo23b2SyZzx9c2CHc4PS_3oGR9snLeArKBCBxPjLR3'
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyngrok: filename=pyngrok-4.1.1-py3-none-any.whl size=15963 sha256=df3ffe998c93fccc169828a808006c7a528796694cb7aacc0f287b1568b4167b
#   Stored in directory: /root/.cache/pip/wheels/4c/7c/4c/632fba2ea8e88d8890102eb07bc922e1ca8fa14db5902c91a8
# Successfully built pyngrok
# ...
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml

# %%
import sys
from google.colab import drive

drive.mount('/content/drive')
sys.path.append('/content/drive/MyDrive/skig_project/')

from flask import Flask, render_template, url_for
from flask_ngrok import run_with_ngrok
templates_folder = '/content/drive/MyDrive/skig_project/templates'
static_folder = '/content/drive/MyDrive/skig_project/static'
app = Flask(__name__, template_folder=templates_folder,static_folder=static_folder)

run_with_ngrok(app)

@app.route("/login")
def login():
    return render_template("index.html")

@app.route("/register")
def register():
    return render_template("register.html")

@app.route("/dashboard")
def dashboard():
    return render_template("dashboard.html")

if __name__ == '__main__':
    app.run()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
#  * Running on http://baf8-35-224-86-42.ngrok-free.app
#  * Traffic stats available on http://127.0.0.1:4040
# INFO:werkzeug:127.0.0.1 - - [12/Dec/2023 13:00:55] "GET / HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [12/Dec/2023 13:00:56] "GET /favicon.ico HTTP/1.1" 404 -
# INFO:werkzeug:127.0.0.1 - - [12/Dec/2023 13:01:00] "GET /login HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [12/Dec/2023 13:01:01] "GET /static/js/uikit.js HTTP/1.1" 200 -
# INFO:werkzeug:127.0.0.1 - - [12/Dec/2023 13:01:01] "GET /static/MDB5/js/mdb.umd.min.js HTTP/1.1" 200 -
# ...
